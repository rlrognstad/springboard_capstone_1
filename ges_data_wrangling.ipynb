# %% [markdown]
# GES data wrangling

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pysal as ps
import scipy.spatial as spatial
# %matplotlib inline

# %% [markdown]
# Read in GES data from csv (2015) or txt (all other years) files

# %%
accident_15 = pd.DataFrame.from_csv('nhtsa-ges-data/GES_2015/ACCIDENT.CSV', index_col=None)
accident_15['YEAR'] = 2015 #add column to specify year, needed when compling multiyear dataset
#accident_15.head()
person_15 = pd.DataFrame.from_csv('nhtsa-ges-data/GES_2015/PERSON.CSV', index_col=None)
person_15['YEAR'] = 2015 #add column to specify year, needed when compling multiyear dataset
#person_15.head()

vehicle_15 = pd.DataFrame.from_csv('nhtsa-ges-data/GES_2015/VEHICLE.CSV', index_col=None, encoding = 'latin-1')
vehicle_15['YEAR'] = 2015 #add column to specify year, needed when compling multiyear dataset
vehicle_15.head()
# Out:
# /home/rlrognstad/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2821: DtypeWarning: Columns (25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
#         CASENUM  VEH_NO  REGION  STRATUM  PJ  PSU  PSUSTRAT  VE_FORMS  \
# 0  201510443751       1       1        4   3    2         3         1
# 1  201510443757       1       1        6   4    2         3         1
# 2  201510443760       1       1        4   4    2         3         2
# 3  201510443760       2       1        4   4    2         3         2
# 4  201510443763       1       1        4  10    2         3         2
#
#    NUMOCCS  MONTH  ...   HITRUN_IM  BDYTYP_IM  MDLYR_IM  IMPACT1_IM  \
# 0        1      1  ...           0          4      2004          12
# 1        1      1  ...           0         31      2005           0
# 2        2      1  ...           0          4      2005          12
# ...

# %% [markdown]
# Read in .txt files, which are tab-delimited and convert to data frames

# %%
accident_14 = pd.read_csv('nhtsa-ges-data/GES_2014/ACCIDENT.TXT',sep='\t',header=(0))
accident_14['YEAR'] = 2014 #add column to specify year, needed when compling multiyear dataset
#accident_14.head()
person_14 = pd.read_csv('nhtsa-ges-data/GES_2014/PERSON.TXT',sep='\t',header=(0))
person_14['YEAR'] = 2014 #add column to specify year, needed when compling multiyear dataset
#person_14.head()

vehicle_14 = pd.read_csv('nhtsa-ges-data/GES_2014/VEHICLE.TXT',sep='\t',header=(0))
vehicle_14['YEAR'] = 2014 #add column to specify year, needed when compling multiyear dataset
#vehicle_14.head()
# Out:
# /home/rlrognstad/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
accident_13 = pd.read_csv('nhtsa-ges-data/GES_2013/ACCIDENT.TXT',sep='\t',header=(0))
accident_13['YEAR'] = 2013 #add column to specify year, needed when compling multiyear dataset
#accident_13.head()
person_13 = pd.read_csv('nhtsa-ges-data/GES_2013/PERSON.TXT',sep='\t',header=(0))
person_13['YEAR'] = 2013 #add column to specify year, needed when compling multiyear dataset
#person_13.head()

vehicle_13 = pd.read_csv('nhtsa-ges-data/GES_2013/VEHICLE.TXT',sep='\t',header=(0))
vehicle_13['YEAR'] = 2013 #add column to specify year, needed when compling multiyear dataset
vehicle_13.head()
# Out:
# /home/rlrognstad/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         CASENUM  VEH_NO  HITRUN_IM  BDYTYP_IM  MDLYR_IM  IMPACT1_IM  \
# 0  201310436487       1          0          4      2010          12
# 1  201310436580       1          0          4      2011          12
# 2  201310436595       1          0          4      2004           6
# 3  201310436595       2          0          4      2004          12
# 4  201310436599       1          0         19      2001          12
#
#    VEVENT_IM  PCRASH1_IM  MXVSEV_IM  NUMINJ_IM  ...   VSURCOND  VTRAFCON  \
# 0         11           1          0          0  ...          1         0
# 1         48           1          0          0  ...          1         0
# 2         12           5          0          0  ...          1         3
# ...

# %%
accident_12 = pd.read_csv('nhtsa-ges-data/GES_2012/ACCIDENT.TXT',sep='\t',header=(0))
accident_12['YEAR'] = 2012 #add column to specify year, needed when compling multiyear dataset
#accident_12.head()
person_12 = pd.read_csv('nhtsa-ges-data/GES_2012/PERSON.TXT',sep='\t',header=(0))
person_12['YEAR'] = 2012 #add column to specify year, needed when compling multiyear dataset
#person_12.head()

vehicle_12 = pd.read_csv('nhtsa-ges-data/GES_2012/VEHICLE.TXT',sep='\t',header=(0))
vehicle_12['YEAR'] = 2012 #add column to specify year, needed when compling multiyear dataset
#vehicle_12.head()
# Out:
# /home/rlrognstad/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
accident_11 = pd.read_csv('nhtsa-ges-data/GES_2011/ACCIDENT.TXT',sep='\t',header=(0))
accident_11['YEAR'] = 2011 #add column to specify year, needed when compling multiyear dataset
#accident_11.head()
person_11 = pd.read_csv('nhtsa-ges-data/GES_2011/PERSON.TXT',sep='\t',header=(0))
person_11['YEAR'] = 2011 #add column to specify year, needed when compling multiyear dataset
#person_11.head()

vehicle_11 = pd.read_csv('nhtsa-ges-data/GES_2011/VEHICLE.TXT',sep='\t',header=(0))
vehicle_11['YEAR'] = 2011 #add column to specify year, needed when compling multiyear dataset
#vehicle_11.head()

# %%
#make combined dataframes
a_frames = [accident_15, accident_14, accident_13, accident_12, accident_11]
accident_all = pd.concat(a_frames)

accident_all.head()
# Out:
#    ALCHL_IM  ALCOHOL       CASENUM  CF1  CF2  CF3  DAY_WEEK  EVENT1_IM  \
# 0         2        2  201510443751  0.0  0.0  0.0         7         59
# 1         2        2  201510443757  0.0  0.0  0.0         7          1
# 2         2        2  201510443760  0.0  0.0  0.0         5         12
# 3         2        2  201510443763  0.0  0.0  0.0         7         12
# 4         2        2  201510443802  0.0  0.0  0.0         7         30
#
#    HARM_EV  HOUR  ...   VE_FORMS  VE_TOTAL  WEATHER  WEATHER1  WEATHER2  \
# 0       59    14  ...          1         1        4         4         0
# 1        1    15  ...          1         1        4         4         0
# 2       12    13  ...          2         2        1         1         0
# 3       12    13  ...          2         2        4         4         0
# 4       30    15  ...          1         1        4         4         0
#
#    WEATHR_IM     WEIGHT  WKDY_IM  WRK_ZONE  YEAR
# 0          4  217.16800        7         0  2015
# ...

# %%
p_frames = [person_15, person_14, person_13, person_12, person_11]
person_all = pd.concat(p_frames)

person_all.head()
# Out:
#    AGE  AGE_IM  AIR_BAG  ALC_RES  ALC_STATUS  ATST_TYP  BODY_TYP  \
# 0   52      52       98      995           8        95      49.0
# 1   27      27       98      995           8        95      49.0
# 2   61      61       98      995           8        95      49.0
# 3   60      60       98      996           0         0      49.0
# 4   25      25       98      995           8        95      66.0
#
#         CASENUM  DRINKING  DRUGRES1  ...   SEX  SEX_IM  SPEC_USE  STRATUM  \
# 0  201510443751         0        95  ...     2       2       0.0        4
# 1  201510443757         0        95  ...     1       1       0.0        6
# 2  201510443760         0        95  ...     1       1       0.0        4
# 3  201510443760         8         0  ...     2       2       0.0        4
# 4  201510443760         0        95  ...     1       1       0.0        4
#
#    STR_VEH  TOW_VEH  VEH_NO  VE_FORMS     WEIGHT  YEAR
# 0        0      0.0       1         1  217.16800  2015
# ...

# %%
v_frames = [vehicle_15, vehicle_14, vehicle_13, vehicle_12, vehicle_11]
vehicle_all = pd.concat(v_frames)

vehicle_all.head()
# Out:
#    ACC_TYPE  BDYTYP_IM  BODY_TYP  BUS_USE  CARGO_BT       CASENUM  DEFORMED  \
# 0         2          4        49        0         0  201510443751         8
# 1        98         31        49        0         0  201510443757         6
# 2        28          4        49        0         0  201510443760         8
# 3        29         66        66        0         2  201510443760         8
# 4        32         39        39        0         0  201510443763         8
#
#    DR_PRES  DR_SF1  DR_SF2  ...   VPROFILE  VSPD_LIM  VSURCOND  VTCONT_F  \
# 0        1     0.0     0.0  ...          1        98         3         0
# 1        1     0.0     0.0  ...          1        98         4         0
# 2        1     0.0     0.0  ...          1        98         1         3
# 3        1     0.0     0.0  ...          1        98         1         3
# 4        1     0.0     0.0  ...          2        98         3         3
#
#    VTRAFCON  VTRAFWAY  V_ALCH_IM  V_CONFIG     WEIGHT  YEAR
# ...

# %%
#compare headers
#list(vehicle_all)
#list(person_all)
#list(accident_all)

#CITY, and COUNTY are only in accident
#combine by STATE and ST_CASE?

# %% [markdown]
# ## Import census data, 2011-2015

# %%
census = pd.DataFrame.from_csv('census_data/cc-est2015-subset.csv', index_col=None, encoding = 'utf-8')
census = census[census['YEAR'] >= 4] #filter out desired census years, 2011:2015
#convert coded census years to actual years, 4=2011; 5=2012; 6=2013; 7=2014; 8=2015
census['YEAR'] = census['YEAR'] + 2007
census.head()
# Out:
#     SUMLEV  STATE  COUNTY   STNAME         CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 57      50      1       1  Alabama  Autauga County  2011       0    55253
# 58      50      1       1  Alabama  Autauga County  2011       1     3581
# 59      50      1       1  Alabama  Autauga County  2011       2     3940
# 60      50      1       1  Alabama  Autauga County  2011       3     4355
# 61      50      1       1  Alabama  Autauga County  2011       4     3954
#
#     TOT_MALE  TOT_FEMALE
# 57     26999       28254
# 58      1864        1717
# 59      1954        1986
# 60      2223        2132
# 61      2033        1921

# %% [markdown]
# ### Write output files

# %%
accident_all.to_csv('wrangled_data/ges_accident_2011_2015.csv', index_label=False )

# %%
person_all.to_csv('wrangled_data/ges_person_2011_2015.csv', index_label=False )

# %%
vehicle_all.to_csv('wrangled_data/ges_vehicle_2011_2015.csv', index_label=False )

# %%
census.to_csv('wrangled_data/census_2011_2015.csv', index_label=False )
